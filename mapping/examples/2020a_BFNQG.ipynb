# %% [markdown]
# # 2020a_BFNQG
# This notebook, associated to the configuration file *config_2020a_BFNQG.py* runs a BFN-QG experiment to map SSH from simulated SWOT and Nadir data

# %% [markdown]
# ## Configuration file

# %%
path_config = 'config_2020a_BFNQG'

# %%
import sys
sys.path.append('..')

# %%
from src import exp
config = exp.Exp(path_config)
# Out:
# name_experiment: 2020a_BFNQG
# saveoutputs: True
# name_exp_save: 2020a_BFNQG
# path_save: ../outputs/2020a_BFNQG
# tmp_DA_path: ../scratch/2020a_BFNQG
# init_date: 2012-10-01 00:00:00
# final_date: 2012-12-09 00:00:00
# assimilation_time_step: 6:00:00
# saveoutput_time_step: 6:00:00
# flag_plot: 0
# name_lon: lon
# name_lat: lat
# name_time: time
# plot_time_step: 1 day, 0:00:00
# time_obs_min: None
# time_obs_max: None
# write_obs: False
# compute_obs: False
# path_obs: None
#
# NAME_OBSOP is not set in the configuration file
# NAME_BASIS is not set in the configuration file

# %% [markdown]
# ## State

# %%
from src import state as state
State = state.State(config)
# Out:
# super: GRID_GEO
# lon_min: 295.0
# lon_max: 305.0
# lat_min: 33.0
# lat_max: 43.0
# dlon: 0.1
# dlat: 0.1
# name_init_mask: None
# name_var_mask: {'lon': '', 'lat': '', 'var': ''}

# %% [markdown]
# ## Observations

# %%
from src import obs as obs
dict_obs = obs.Obs(config,State)
# Out:
# Observation information will be saved in dict_obs_J1_EN_TPN_G2_20121001_20121209_295_305_33_43.txt
#
# J1:
# super: OBS_SSH_NADIR
# path: ../../data/2020a_SSH_mapping_NATL60/dc_obs/2020a_SSH_mapping_NATL60_jason1.nc
# name_time: time
# name_lon: lon
# name_lat: lat
# name_var: {'SSH': 'ssh_model'}
# sigma_noise: None
# add_mdt: None
# substract_mdt: None
# path_mdt: None
# name_var_mdt: None
# nudging_params_ssh: {'sigma': 0, 'K': 0.7, 'Tau': datetime.timedelta(days=1)}
# detrend: False
#
# --> 85 tracks selected
#
# EN:
# super: OBS_SSH_NADIR
# path: ../../data/2020a_SSH_mapping_NATL60/dc_obs/2020a_SSH_mapping_NATL60_envisat.nc
# name_time: time
# name_lon: lon
# name_lat: lat
# name_var: {'SSH': 'ssh_model'}
# sigma_noise: None
# add_mdt: None
# substract_mdt: None
# path_mdt: None
# name_var_mdt: None
# nudging_params_ssh: {'sigma': 0, 'K': 0.7, 'Tau': datetime.timedelta(days=1)}
# detrend: False
#
# --> 74 tracks selected
#
# TPN:
# super: OBS_SSH_NADIR
# path: ../../data/2020a_SSH_mapping_NATL60/dc_obs/2020a_SSH_mapping_NATL60_topex-poseidon_interleaved.nc
# name_time: time
# name_lon: lon
# name_lat: lat
# name_var: {'SSH': 'ssh_model'}
# sigma_noise: None
# add_mdt: None
# substract_mdt: None
# path_mdt: None
# name_var_mdt: None
# nudging_params_ssh: {'sigma': 0, 'K': 0.7, 'Tau': datetime.timedelta(days=1)}
# detrend: False
#
# --> 78 tracks selected
#
# G2:
# super: OBS_SSH_NADIR
# path: ../../data/2020a_SSH_mapping_NATL60/dc_obs/2020a_SSH_mapping_NATL60_geosat2.nc
# name_time: time
# name_lon: lon
# name_lat: lat
# name_var: {'SSH': 'ssh_model'}
# sigma_noise: None
# add_mdt: None
# substract_mdt: None
# path_mdt: None
# name_var_mdt: None
# nudging_params_ssh: {'sigma': 0, 'K': 0.7, 'Tau': datetime.timedelta(days=1)}
# detrend: False
#
# --> 87 tracks selected

# %% [markdown]
# ## Model

# %%
from src import mod as mod
Model = mod.Model(config,State)
# Out:
# super: MOD_QG1L_NP
# name_var: {'SSH': 'ssh', 'PV': 'pv'}
# name_init_var: {}
# dir_model: None
# dtmodel: 1200
# upwind: 3
# upwind_adj: None
# Reynolds: False
# qgiter: 20
# qgiter_adj: None
# c0: 2.7
# filec_aux: None
# name_var_c: {'lon': '', 'lat': '', 'var': ''}
# cmin: None
# cmax: None
# only_diffusion: False
# path_mdt: None
# name_var_mdt: {'lon': '', 'lat': '', 'mdt': '', 'mdu': '', 'mdv': ''}
# g: 9.81

# %% [markdown]
# ## Boundary conditions

# %%
from src import bc as bc
Bc = bc.Bc(config)
# Out:
# super: BC_EXT
# file: ../../data/2020a_SSH_mapping_NATL60/2020a_SSH_mapping_NATL60_DUACS_swot_en_j1_tpn_g2.nc
# name_lon: lon
# name_lat: lat
# name_time: time
# name_var: {'SSH': 'gssh'}
# name_mod_var: {'SSH': 'ssh'}
# dist_sponge: 50
#
# <xarray.Dataset>
# Dimensions:  (lon: 394, lat: 162, time: 365)
# Coordinates:
#   * lon      (lon) float64 -90.12 -89.88 -89.62 -89.38 ... 7.625 7.875 8.125
#   * lat      (lat) float64 26.88 27.12 27.38 27.62 ... 66.38 66.62 66.88 67.12
#   * time     (time) datetime64[ns] 2012-10-01 2012-10-02 ... 2013-09-30
# Data variables:
#     gssh     (time, lat, lon) float64 dask.array<chunksize=(365, 162, 394), meta=np.ndarray>

# %% [markdown]
# ## Inversion

# %%
from src import inv as inv
inv.Inv(config,State,Model,dict_obs=dict_obs,Bc=Bc)
# Out:
# super: INV_BFN
# window_size: 7 days, 0:00:00
# window_output: 3 days, 0:00:00
# propagation_timestep: 3:00:00
# window_overlap: True
# criterion: 0.01
# max_iteration: 10
# save_trajectory: False
# dist_scale: 10
# save_obs_proj: False
# path_save_proj: None
# use_bc_as_init: False
# scalenudg: None
#
# Loop from 2012-10-01 to 2012-10-08 : 5 iterations in 0:03:37.456063 seconds
# Loop from 2012-10-02 to 2012-10-09 : 4 iterations in 0:02:42.857303 seconds
# Loop from 2012-10-04 to 2012-10-11 : 3 iterations in 0:01:46.649058 seconds
# Loop from 2012-10-05 to 2012-10-12 : 5 iterations in 0:03:31.311116 seconds
# Loop from 2012-10-07 to 2012-10-14 : 4 iterations in 0:02:45.686891 seconds
# Loop from 2012-10-08 to 2012-10-15 : 4 iterations in 0:02:43.409539 seconds
# Loop from 2012-10-10 to 2012-10-17 : 4 iterations in 0:02:31.397810 seconds
# Loop from 2012-10-11 to 2012-10-18 : 4 iterations in 0:02:35.232594 seconds
# Loop from 2012-10-13 to 2012-10-20 : 4 iterations in 0:02:49.201523 seconds
# Loop from 2012-10-14 to 2012-10-21 : 4 iterations in 0:02:49.502103 seconds
# Loop from 2012-10-16 to 2012-10-23 : 4 iterations in 0:02:39.151522 seconds
# Loop from 2012-10-17 to 2012-10-24 : 4 iterations in 0:02:42.936459 seconds
# Loop from 2012-10-19 to 2012-10-26 : 4 iterations in 0:02:34.915020 seconds
# Loop from 2012-10-20 to 2012-10-27 : 3 iterations in 0:01:53.749999 seconds
# Loop from 2012-10-22 to 2012-10-29 : 4 iterations in 0:02:29.943100 seconds
# Loop from 2012-10-23 to 2012-10-30 : 3 iterations in 0:01:48.796344 seconds
# Loop from 2012-10-25 to 2012-11-01 : 4 iterations in 0:02:39.705852 seconds
# Loop from 2012-10-26 to 2012-11-02 : 4 iterations in 0:02:33.466145 seconds
# Loop from 2012-10-28 to 2012-11-04 : 4 iterations in 0:02:49.092806 seconds
# Loop from 2012-10-29 to 2012-11-05 : 4 iterations in 0:02:57.893102 seconds
# Loop from 2012-10-31 to 2012-11-07 : 4 iterations in 0:02:36.845896 seconds
# Loop from 2012-11-01 to 2012-11-08 : 4 iterations in 0:02:35.435633 seconds
# Loop from 2012-11-03 to 2012-11-10 : 4 iterations in 0:02:45.656250 seconds
# Loop from 2012-11-04 to 2012-11-11 : 4 iterations in 0:02:34.120097 seconds
# Loop from 2012-11-06 to 2012-11-13 : 4 iterations in 0:02:36.906369 seconds
# Loop from 2012-11-07 to 2012-11-14 : 4 iterations in 0:02:49.852637 seconds
# Loop from 2012-11-09 to 2012-11-16 : 4 iterations in 0:02:37.020913 seconds
# Loop from 2012-11-10 to 2012-11-17 : 4 iterations in 0:02:49.023675 seconds
# Loop from 2012-11-12 to 2012-11-19 : 4 iterations in 0:02:45.285441 seconds
# Loop from 2012-11-13 to 2012-11-20 : 4 iterations in 0:02:37.554946 seconds
# Loop from 2012-11-15 to 2012-11-22 : 4 iterations in 0:02:42.810637 seconds
# Loop from 2012-11-16 to 2012-11-23 : 4 iterations in 0:02:45.008086 seconds
# Loop from 2012-11-18 to 2012-11-25 : 4 iterations in 0:02:36.747008 seconds
# Loop from 2012-11-19 to 2012-11-26 : 4 iterations in 0:02:40.733438 seconds
# Loop from 2012-11-21 to 2012-11-28 : 4 iterations in 0:02:39.119331 seconds
# Loop from 2012-11-22 to 2012-11-29 : 4 iterations in 0:02:43.780837 seconds
# Loop from 2012-11-24 to 2012-12-01 : 4 iterations in 0:02:45.671066 seconds
# Loop from 2012-11-25 to 2012-12-02 : 4 iterations in 0:02:49.368312 seconds
# Loop from 2012-11-27 to 2012-12-04 : 4 iterations in 0:02:41.828851 seconds
# Loop from 2012-11-28 to 2012-12-05 : 3 iterations in 0:01:52.432355 seconds
# Loop from 2012-11-30 to 2012-12-07 : 3 iterations in 0:02:10.188758 seconds
# Loop from 2012-12-01 to 2012-12-08 : 4 iterations in 0:02:35.839410 seconds
# Loop from 2012-12-03 to 2012-12-09 : 4 iterations in 0:02:15.065019 seconds

# %% [markdown]
# ## Diagnostics

# %%
from src import diag as diag
Diag = diag.Diag(config,State)
# Out:
# super: DIAG_OSSE
# dir_output: ../diags/2020a_BFNQG
# time_min: 2012-10-22 00:00:00
# time_max: 2012-12-02 00:00:00
# lon_min: None
# lon_max: None
# lat_min: None
# lat_max: None
# name_ref: ../../data/2020a_SSH_mapping_NATL60/dc_ref/NATL60-CJM165_GULFSTREAM*.nc
# name_ref_time: time
# name_ref_lon: lon
# name_ref_lat: lat
# name_ref_var: sossheig
# options_ref: {'combine': 'nested', 'concat_dim': 'time', 'parallel': True}
# name_exp_var: ssh

# %%
Diag.regrid_exp()

# %%
Diag.rmse_based_scores(plot=True)

# %%
Diag.psd_based_scores(plot=True)
# Out:
# /home/fleguillou/anaconda3/envs/env-plot/lib/python3.10/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(
# /home/fleguillou/anaconda3/envs/env-plot/lib/python3.10/site-packages/xrft/xrft.py:47: FutureWarning: Please provide the name of window adhering to scipy.signal.windows. The boolean option will be deprecated in future releases.
#   warnings.warn(

# %%
Diag.movie(framerate=12)
# Out:
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 10.3.0 (GCC)
#   configuration: --prefix=/home/fleguillou/anaconda3/envs/env-plot --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1645955405450/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1645955405450/_build_env/bin/pkg-config
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, image2, from '../diags/2020a_BFNQG/frame_*.png':
#   Duration: 00:00:13.58, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 1800x1000 [SAR 3937:3937 DAR 9:5], 12 fps, 12 tbr, 12 tbn, 12 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55c3548a5780] using SAR=1/1
# [libx264 @ 0x55c3548a5780] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX
# [libx264 @ 0x55c3548a5780] profile High, level 5.1, 4:2:0, 8-bit
# [libx264 @ 0x55c3548a5780] 264 - core 161 r3030M 8bd6d28 - H.264/MPEG-4 AVC codec - Copyleft 2003-2020 - http://www.videolan.org/x264.html - options: cabac=1 ref=16 deblock=1:0:0 analyse=0x3:0x133 me=umh subme=10 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=24 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=24 lookahead_threads=4 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=8 b_pyramid=2 b_adapt=2 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=12 scenecut=40 intra_refresh=0 rc_lookahead=60 rc=crf mbtree=1 crf=15.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '../diags/2020a_BFNQG/movie.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1800x1000 [SAR 1:1 DAR 9:5], q=-1--1, 12 fps, 12288 tbn, 12 tbc
#     Metadata:
#       encoder         : Lavc58.91.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  163 fps= 16 q=-1.0 Lsize=    1432kB time=00:00:13.33 bitrate= 879.9kbits/s speed=1.31x
# video:1430kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.173847%
# [libx264 @ 0x55c3548a5780] frame I:1     Avg QP: 9.59  size: 66454
# [libx264 @ 0x55c3548a5780] frame P:32    Avg QP:10.91  size: 18826
# [libx264 @ 0x55c3548a5780] frame B:130   Avg QP:16.16  size:  6110
# [libx264 @ 0x55c3548a5780] consecutive B-frames:  0.6%  0.0%  1.8% 41.7% 12.3% 11.0% 17.2%  9.8%  5.5%
# [libx264 @ 0x55c3548a5780] mb I  I16..4: 33.9% 53.8% 12.3%
# [libx264 @ 0x55c3548a5780] mb P  I16..4:  0.8%  2.8%  0.7%  P16..4:  6.0%  6.9%  7.2%  0.4%  0.1%    skip:75.1%
# [libx264 @ 0x55c3548a5780] mb B  I16..4:  0.1%  0.2%  0.1%  B16..8:  8.4%  6.0%  2.1%  direct: 1.5%  skip:81.6%  L0:47.8% L1:37.4% BI:14.7%
# [libx264 @ 0x55c3548a5780] 8x8 transform intra:59.9% inter:55.0%
# [libx264 @ 0x55c3548a5780] direct mvs  spatial:89.2% temporal:10.8%
# [libx264 @ 0x55c3548a5780] coded y,uvDC,uvAC intra: 41.3% 56.5% 51.7% inter: 4.1% 3.9% 1.1%
# [libx264 @ 0x55c3548a5780] i16 v,h,dc,p: 68% 21%  4%  7%
# [libx264 @ 0x55c3548a5780] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 19% 27%  4%  5%  4%  7%  4%  7%
# [libx264 @ 0x55c3548a5780] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 19% 18%  5% 11%  8% 10%  5%  7%
# [libx264 @ 0x55c3548a5780] i8c dc,h,v,p: 60% 22%  9%  9%
# [libx264 @ 0x55c3548a5780] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55c3548a5780] ref P L0: 45.4%  4.0% 15.8%  5.5%  5.0%  3.7%  3.4%  2.1%  2.2%  1.9%  1.8%  1.7%  1.8%  2.1%  1.7%  1.8%
# [libx264 @ 0x55c3548a5780] ref B L0: 73.6% 11.5%  4.4%  2.4%  1.6%  1.2%  1.0%  0.7%  0.7%  0.6%  0.6%  0.6%  0.6%  0.4%  0.2%
# [libx264 @ 0x55c3548a5780] ref B L1: 95.3%  4.7%
# [libx264 @ 0x55c3548a5780] kb/s:861.78

# %%
import os
from IPython.display import Video
Video(os.path.join(Diag.dir_output, 'movie.mp4'))
# Out:
# <video src="../diags/2020a_BFNQG/movie.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
Leaderboard = Diag.Leaderboard()
Leaderboard
# Out:
#         Method  µ(RMSE)   σ(RMSE)  λx (degree)  λt (days)
# 0  2020a_BFNQG      0.85     0.02         1.21      10.91
