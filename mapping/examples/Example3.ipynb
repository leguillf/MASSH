# %% [markdown]
# # Example 2
# This notebook, associated to the configuration file *config_Example2.py* runs a 4Dvar-SW experiment to map SSH from idealized SSH data

# %% [markdown]
# ## Configuration file

# %%
path_config = 'config_Example3_BM.py'

# %%
import os
os.chdir('..')
import sys
sys.path.append('src')

# %%
from src import exp
config = exp.exp(path_config)

# %%
config.flag_plot = 4

# %% [markdown]
# ## State

# %%
from src import state as state
State = state.State(config)

# %% [markdown]
# ## Model

# %%
from src import mod as mod
Model = mod.Model(config,State)
# Out:
# Model: QG1L

# %% [markdown]
# ## Observations

# %%
from src import obs as obs
dict_obs = obs.obs(config,State)
# Out:
# * for sat nr :
#  satellite : nr
#  kind : fullSSH
#  path : .
#  name : ../data_Example3/obs_ssh_BMs_ITs_0h23m50.nc
# 2012-07-02 23:00:00 : scratch/Example3_BM/obs_20120702_23h00.nc
# 2012-07-03 23:00:00 : scratch/Example3_BM/obs_20120703_23h00.nc
# 2012-07-04 23:00:00 : scratch/Example3_BM/obs_20120704_23h00.nc
# 2012-07-05 23:00:00 : scratch/Example3_BM/obs_20120705_23h00.nc
# 2012-07-06 22:00:00 : scratch/Example3_BM/obs_20120706_22h00.nc
# /Users/leguillou/WORK/Developpement/Studies/MASSH/mapping/src/obs.py:228: SerializationWarning: saving variable lat with floating point data as an integer dtype without any _FillValue to use for NaNs
#   ds1.to_netcdf(path)
# 2012-07-07 22:00:00 : scratch/Example3_BM/obs_20120707_22h00.nc
# 2012-07-08 22:00:00 : scratch/Example3_BM/obs_20120708_22h00.nc
# 2012-07-09 22:00:00 : scratch/Example3_BM/obs_20120709_22h00.nc
# 2012-07-10 22:00:00 : scratch/Example3_BM/obs_20120710_22h00.nc
# 2012-07-11 22:00:00 : scratch/Example3_BM/obs_20120711_22h00.nc
# 2012-07-12 21:00:00 : scratch/Example3_BM/obs_20120712_21h00.nc
# 2012-07-13 21:00:00 : scratch/Example3_BM/obs_20120713_21h00.nc
# 2012-07-14 21:00:00 : scratch/Example3_BM/obs_20120714_21h00.nc
# 2012-07-15 21:00:00 : scratch/Example3_BM/obs_20120715_21h00.nc
# 2012-07-16 21:00:00 : scratch/Example3_BM/obs_20120716_21h00.nc
# 2012-07-17 21:00:00 : scratch/Example3_BM/obs_20120717_21h00.nc
# 2012-07-18 20:00:00 : scratch/Example3_BM/obs_20120718_20h00.nc
# 2012-07-19 20:00:00 : scratch/Example3_BM/obs_20120719_20h00.nc

# %% [markdown]
# ## Assimilation

# %%
from src import ana as ana
ana.ana(config,State,Model,dict_obs=dict_obs)
# Out:
# /Users/leguillou/WORK/Developpement/Studies/MASSH/mapping/src/grid.py:239: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   im0 = ax0.pcolormesh(lon2d, lat2d, var_bc_interpTime[0],cmap='RdBu_r')
# /Users/leguillou/WORK/Developpement/Studies/MASSH/mapping/src/grid.py:242: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   im1 = ax1.pcolormesh(lon2d, lat2d, bc_weight)
# Loop from 2012-07-01 to 2012-07-20 : 1 iterations in 0:02:53.958263 seconds

# %% [markdown]
# ## Visualize outputs

# %%
ds = State.load_output(config.final_date)
ds.ssh.plot()
